# %%
import pandas as pd

# %%
df=pd.read_csv('/content/redaction_train_set - PII.csv',names=["Text"])

# %%
df1=pd.read_csv('/content/redaction_train_set - No PII.csv',names=["Text"])

# %%
df
# Out:
#                                                   Text
# 0    Hi, my name is Emma Thompson, and I have forgo...
# 1    Hello, my name is Alex Johnson, and I need to ...
# 2    Hi there, I'm Chris Evans and I need to reset ...
# 3    Good morning, my name is Emily Roberts. I need...
# 4    Hey, I'm James Davis and I can't remember the ...
# ..                                                 ...
# 594  I need to update my bank account information. ...
# 595  I'm having trouble logging in. My passcode is ...
# 596  I can't remember my password. My passport numb...
# 597  Hi, I need some help with my account. My email...
# 598  I'm having difficulty accessing my account. My...
#
# [599 rows x 1 columns]

# %%
# !pip install presidio_analyzer
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.4/97.4 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 9.6 MB/s eta 0:00:00
# ...

# %%
# !python -m spacy download en_core_web_lg
# Out:
# 2023-09-21 22:55:24.521782: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-21 22:55:27.726743: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 2.6 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
configuration = {
    "nlp_engine_name": "spacy",
    "models": [{"lang_code": "en", "model_name": "en_core_web_lg"}],
}

# %%
from presidio_analyzer import AnalyzerEngine
from presidio_analyzer.nlp_engine import NlpEngineProvider
# Create NLP engine based on configuration
provider = NlpEngineProvider(nlp_configuration=configuration)
nlp_engine = provider.create_engine()
# the languages are needed to load country-specific recognizers
# for finding phones, passport numbers, etc.
analyzer = AnalyzerEngine(nlp_engine=nlp_engine,
                          supported_languages=["en"])

# %%
results = analyzer.analyze(text=df["Text"][0],
                           language='en')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-ff88de72c91f> in <cell line: 1>()
# ----> 1 results = analyzer.analyze(text=df["Text"][0],
#       2                            language='en')
#
# NameError: name 'df' is not defined

# %%
results_list = []

# Loop through each row in the DataFrame
for index, row in df.iterrows():
    text = row["Text"]
    # Analyze the text and store the result in the list
    results = analyzer.analyze(text=text, language='en')
    results_list.append(results)

# Add the results list as a new column in the DataFrame
df["Annotated_Text"] = results_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-dc6b5ef31a00> in <cell line: 4>()
#       2
#       3 # Loop through each row in the DataFrame
# ----> 4 for index, row in df.iterrows():
#       5     text = row["Text"]
#       6     # Analyze the text and store the result in the list
#
# NameError: name 'df' is not defined

# %%
df1
# Out:
#                                                   Text
# 0    Hi there! I recently purchased one of your pro...
# 1    I'm having trouble accessing the online user m...
# 2    I noticed a small defect in the packaging of t...
# 3    I've been experiencing some technical difficul...
# 4    Is there a way to extend the warranty coverage...
# ..                                                 ...
# 244  Can you provide the dimensions and weight of a...
# 245  I would like to know if your company offers gi...
# 246  I have a general inquiry about the loyalty rew...
# 247  Is it possible to receive a refund for an onli...
# 248  Can you provide instructions on how to update ...
#
# [249 rows x 1 columns]

# %%
results_list1 = []

# Loop through each row in the DataFrame
for index, row in df1.iterrows():
    text = row["Text"]
    # Analyze the text and store the result in the list
    results = analyzer.analyze(text=text, language='en')
    results_list1.append(results)

# Add the results list as a new column in the DataFrame
df1["Annotated_Text"] = results_list1

# %%
df1.to_csv('No_PII.csv')

# %%
df.to_csv('Annotated_data.csv')

# %%
results
# Out:
# [type: EMAIL_ADDRESS, start: 91, end: 115, score: 1.0,
#  type: PERSON, start: 15, end: 28, score: 0.85,
#  type: URL, start: 106, end: 115, score: 0.5]

# %%
# !pip install presidio_analyzer

# %%
# !python -m spacy download en_core_web_lg
# Out:
# 2023-09-21 22:57:03.031144: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
#   Using cached https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.6.0/en_core_web_lg-3.6.0-py3-none-any.whl (587.7 MB)
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
configuration = {
    "nlp_engine_name": "spacy",
    "models": [{"lang_code": "en", "model_name": "en_core_web_lg"}],
}

# %%
from presidio_analyzer import AnalyzerEngine
from presidio_analyzer.nlp_engine import NlpEngineProvider

# %%
def generate_annotation(text):
  provider = NlpEngineProvider(nlp_configuration=configuration)
  nlp_engine = provider.create_engine()
  analyzer = AnalyzerEngine(nlp_engine=nlp_engine,
                          supported_languages=["en"])
  results = analyzer.analyze(text=text,
                           language='en')
  return results

# %%
res=generate_annotation("I'd like to inquire about the warranty coverage for a product I bought last month.")

# %%
res
# Out:
# [type: DATE_TIME, start: 71, end: 81, score: 0.85]

# %%
# !pip install flair
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 373.1/373.1 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 788.5/788.5 kB 24.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 13.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 43.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 37.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 30.0 MB/s eta 0:00:00
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 23.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %%
pip install --upgrade pyOpenSSL

# %%
pip install --upgrade urllib3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 2.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.16
#     Uninstalling urllib3-1.26.16:
#       Successfully uninstalled urllib3-1.26.16
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# botocore 1.31.52 requires urllib3<1.27,>=1.25.4, but you have urllib3 2.0.5 which is incompatible.
# torchdata 0.6.1 requires torch==2.0.1, but you have torch 2.0.0 which is incompatible.
# torchtext 0.15.2 requires torch==2.0.1, but you have torch 2.0.0 which is incompatible.
# torchvision 0.15.2+cu118 requires torch==2.0.1, but you have torch 2.0.0 which is incompatible.
# ...

# %% [markdown]
# **Flair**

# %%
from flair.data import Sentence
from flair.nn import Classifier

# make a sentence
sentence = Sentence('Hello, my name is Alex Johnson, and I need to update my address. My new address is 123 Apple Street, New York City, NY 10001.')

# load the NER tagger
tagger = Classifier.load('ner')

# run NER over sentence
tagger.predict(sentence)

# print the sentence with all annotations
print(sentence)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-904bc6cb6535> in <cell line: 1>()
# ----> 1 from flair.data import Sentence
#       2 from flair.nn import Classifier
#       3
#       4 # make a sentence
#       5 sentence = Sentence('Hello, my name is Alex Johnson, and I need to update my address. My new address is 123 Apple Street, New York City, NY 10001.')
#
# /usr/local/lib/python3.10/dist-packages/flair/__init__.py in <module>
#       7
#       8 # global variable: cache_root
# ----> 9 from .file_utils import set_proxies
#      10
#      11 cache_root = Path(os.getenv("FLAIR_CACHE_ROOT", Path(Path.home(), ".flair")))
#
# /usr/local/lib/python3.10/dist-packages/flair/file_utils.py in <module>
#      18 from urllib.parse import urlparse
#      19
# ---> 20 import boto3
#      21 import requests
#      22 import torch
#
# ...

# %% [markdown]
# **Flair-Onto Notes**

# %%
from flair.data import Sentence
from flair.models import SequenceTagger

# load tagger
tagger = SequenceTagger.load("flair/ner-english-ontonotes")

# make example sentence
# Out:
# 2023-09-21 20:30:56,398 SequenceTagger predicts: Dictionary with 75 tags: O, S-PERSON, B-PERSON, E-PERSON, I-PERSON, S-GPE, B-GPE, E-GPE, I-GPE, S-ORG, B-ORG, E-ORG, I-ORG, S-DATE, B-DATE, E-DATE, I-DATE, S-CARDINAL, B-CARDINAL, E-CARDINAL, I-CARDINAL, S-NORP, B-NORP, E-NORP, I-NORP, S-MONEY, B-MONEY, E-MONEY, I-MONEY, S-PERCENT, B-PERCENT, E-PERCENT, I-PERCENT, S-ORDINAL, B-ORDINAL, E-ORDINAL, I-ORDINAL, S-LOC, B-LOC, E-LOC, I-LOC, S-TIME, B-TIME, E-TIME, I-TIME, S-WORK_OF_ART, B-WORK_OF_ART, E-WORK_OF_ART, I-WORK_OF_ART, S-FAC

# %%
results_list1 = []

# Loop through each row in the DataFrame
for index, row in df1.iterrows():
    text = row["Text"]
    # Analyze the text and store the result in the list
    results = analyzer.analyze(text=text, language='en')
    results_list1.append(results)

# Add the results list as a new column in the DataFrame
df1["Annotated_Text"] = results_list1

# %%
annotations=[]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-63878e972779> in <cell line: 1>()
#       2     annotations.append({
#       3         'text': entity.text,
# ----> 4         'start_pos': entity.start_pos,
#       5         'end_pos': entity.end_pos,
#       6         'label': entity.tag,
#
# AttributeError: 'Span' object has no attribute 'start_pos'

# %%
sentence = Sentence("Good morning, my name is Emily Roberts. I need assistance with updating the expiration date on my credit card. The card number is 4567890123456789 and it expires in January next year.")

# predict NER tags
tagger.predict(sentence)
annotations=[]
for entity in sentence.get_spans('ner'):
    annotations.append(entity)
# print sentence
print(annotations)
# Out:
# [Span[1:2]: "morning" → TIME (0.5927), Span[6:8]: "Emily Roberts" → PERSON (0.9334), Span[31:34]: "January next year" → DATE (0.925)]

# %%
results_list_flair = []

# Loop through each row in the DataFrame
for index, row in df.iterrows():
    text = row["Text"]
    # Analyze the text and store the result in the list
    tagger.predict(sentence)
    annotations=[]
    for entity in sentence.get_spans('ner'):
        annotations.append(entity)
        results_list1.append(results)

# Add the results list as a new column in the DataFrame
df1["Annotated_Text"] = results_list1

# %%
from flair.data import Sentence
from flair.models import SequenceTagger

# load tagger
tagger1 = SequenceTagger.load("flair/ner-english")

# make example sentence
# Out:
# 2023-09-21 20:32:18,738 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>

# %%
sentence = Sentence("Good morning, my name is Emily Roberts. I need assistance with updating the expiration date on my credit card. The card number is 4567890123456789 and it expires in 2/11/2001")

# predict NER tags
tagger1.predict(sentence)

# %%
print('The following NER tags are found:')
# iterate over entities and print
for entity in sentence.get_spans('ner'):
    print(entity)
# Out:
# The following NER tags are found:
# Span[6:8]: "Emily Roberts" → PER (0.997)

# %%
pip install -U span_marker
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.5/41.5 kB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.3 MB/s eta 0:00:00
# ...
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=1a6ae58a59807f734ff41118f5a21f6fbb630a378ee8a8edd24070dec75e87cd
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# ...

# %%
from span_marker import SpanMarkerModel

model = SpanMarkerModel.from_pretrained("tomaarsen/span-marker-bert-base-fewnerd-fine-super")

# %%
model.predict("Good morning, my name is Emily Roberts. I need assistance with updating the expiration date on my credit card. The card number is 4567890123456789 and it expires in 2/11/2001")
# Out:
# [{'span': 'Emily Roberts',
#   'label': 'person-other',
#   'score': 0.9811272025108337,
#   'char_start_index': 25,
#   'char_end_index': 38}]

# %%
model_span = SpanMarkerModel.from_pretrained("tomaarsen/span-marker-roberta-large-ontonotes5")

# %%
res=model_span.predict("Good day, it's Mateo Anderson here and I need help with adding a new beneficiary for international transfers. Thanks John and Mateo")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d4b3a154fd5b> in <cell line: 1>()
# ----> 1 res=model_span.predict("Good day, it's Mateo Anderson here and I need help with adding a new beneficiary for international transfers. Thanks John and Mateo")
#
# NameError: name 'model_span' is not defined

# %%
res
# Out:
# [{'span': 'morning',
#   'label': 'TIME',
#   'score': 0.6428206562995911,
#   'char_start_index': 5,
#   'char_end_index': 12},
#  {'span': 'Emily Roberts',
#   'label': 'PERSON',
#   'score': 0.9994513392448425,
#   'char_start_index': 25,
#   'char_end_index': 38},
#  {'span': '2/11/2001',
#   'label': 'DATE',
#   'score': 0.9941748976707458,
#   'char_start_index': 165,
#   'char_end_index': 174}]

# %%
+results_list = []

# Loop through each row in the DataFrame
for index, row in df.iterrows():
    text = row["Text"]
    # Analyze the text and store the result in the list
    results = model_span.predict(text)
    results_list.append(results)

# Add the results list as a new column in the DataFrame
df["Annotated_Text"] = results_list
